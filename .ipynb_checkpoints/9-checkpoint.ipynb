# %%
## feature extraction with SIFT algorithm
## feature extraction algorithm
# !pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.8 MB)
#      |████████████████████████████████| 67.8 MB 53 kB/s  eta 0:00:013   |▌                               | 962 kB 724 kB/s eta 0:01:33     |██                              | 4.5 MB 4.6 MB/s eta 0:00:14     |██▍                             | 5.1 MB 4.6 MB/s eta 0:00:14     |██▋                             | 5.4 MB 4.6 MB/s eta 0:00:14     |███                             | 6.4 MB 4.6 MB/s eta 0:00:14     |███▌                            | 7.3 MB 4.6 MB/s eta 0:00:14     |█████▉                          | 12.4 MB 1.4 MB/s eta 0:00:41     |███████▌                        | 15.9 MB 6.7 MB/s eta 0:00:08     |█████████▊                      | 20.5 MB 5.8 MB/s eta 0:00:09     |██████████▌                     | 22.3 MB 5.8 MB/s eta 0:00:08     |██████████▊                     | 22.6 MB 5.8 MB/s eta 0:00:08     |███████████▏                    | 23.7 MB 5.8 MB/s eta 0:00:08     |███████████▌                    | 24.3 MB 5.8 MB/s eta 0:00:08     |███████████▊                    | 24.8 MB 5.8 MB/s eta 0:00:08     |████████████                    | 25.3 MB 5.8 MB/s eta 0:00:08     |█████████████▌                  | 28.7 MB 8.6 MB/s eta 0:00:05     |██████████████                  | 29.5 MB 8.6 MB/s eta 0:00:05     |██████████████▌                 | 30.8 MB 8.6 MB/s eta 0:00:05     |█████████████████▏              | 36.5 MB 11.6 MB/s eta 0:00:03     |███████████████████▊            | 41.9 MB 2.6 MB/s eta 0:00:11     |████████████████████▏           | 42.8 MB 2.6 MB/s eta 0:00:10     |███████████████████████▉        | 50.6 MB 5.8 MB/s eta 0:00:03     |████████████████████████▉       | 52.7 MB 5.8 MB/s eta 0:00:03     |█████████████████████████▎      | 53.6 MB 5.0 MB/s eta 0:00:03     |██████████████████████████▌     | 56.1 MB 5.0 MB/s eta 0:00:03     |███████████████████████████     | 57.1 MB 5.0 MB/s eta 0:00:03     |███████████████████████████▋    | 58.6 MB 5.7 MB/s eta 0:00:02     |████████████████████████████▍   | 60.2 MB 5.7 MB/s eta 0:00:02     |████████████████████████████▊   | 60.8 MB 5.7 MB/s eta 0:00:02     |█████████████████████████████▋  | 62.6 MB 5.3 MB/s eta 0:00:01     |██████████████████████████████  | 63.7 MB 5.3 MB/s eta 0:00:01     |██████████████████████████████▍ | 64.3 MB 5.3 MB/s eta 0:00:01     |███████████████████████████████ | 65.6 MB 5.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /home/tanvir/anaconda3/lib/python3.9/site-packages (from opencv-contrib-python) (1.20.0)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.8.1.78

# %%
import numpy as np
import skimage
import cv2
import math
import matplotlib
import matplotlib.pyplot as plt
import albumentations    as albu  ## for image augmentation
from skimage import io
from skimage import data
from skimage import img_as_float
from skimage import img_as_ubyte
from skimage import util
from skimage.restoration import denoise_tv_chambolle,denoise_bilateral,denoise_wavelet,estimate_sigma
from skimage.util import random_noise
from skimage.color import rgb2gray
from skimage.transform import resize,rescale

def image_prop(image):
    print("-"*50)
    print("Type         :  ",type(image))
    print("DType        :  ",image.dtype)
    print("Shape        :  ",image.shape)
    print("size         :  ",image.size)
    print("High Pixel   :  ",image.max())
    print("Lowes Pixel  :  ",image.min())
    print("Aspect Ratio :  ",image.shape[1]/float(image.shape[0]))
    
    print("-"*50)
    
def plot_image(image):
    plt.figure(figsize=(10,10))
    if image.shape[2]:
        
        if image.shape[2] == 3:    
            plt.imshow(image)
        else:
            plt.imshow(image,cmap="gray")
    else:
        plt.imshow(image,cmap="gray")
    plt.colorbar()
    image_prop(image)

# %%
img1 = cv2.imread("./datasets/images/taj_small.jpg")
plot_image(img1)
# Out:
# --------------------------------------------------
# Type         :   <class 'numpy.ndarray'>
# DType        :   uint8
# Shape        :   (540, 999, 3)
# size         :   1618380
# High Pixel   :   255
# Lowes Pixel  :   0
# Aspect Ratio :   1.85
# --------------------------------------------------

# %%
## convert to grayscale image
gray1 = rgb2gray(img1)
plot_image(gray1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 ## convert to grayscale image
#       2 gray1 = rgb2gray(img1)
# ----> 3 plot_image(gray1)
#
# Input In [4], in plot_image(image)
#      30 def plot_image(image):
#      31     plt.figure(figsize=(10,10))
# ---> 32     if image.shape[2] == 3:
#      33         plt.imshow(image)
#      34     else:
#
# IndexError: tuple index out of range
